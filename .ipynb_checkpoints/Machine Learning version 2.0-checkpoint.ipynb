# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import metrics
import random

import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
# import the data
df = pd.read_csv("collected data9.6.2019/merged_data.csv", index_col=0)

# %%
# calculate total minutes of play time for each player by reversing formula spm * minutes = score
df['minutes'] = df['score']/df['spm']
df['kpm'] = df['kills']/df['minutes']

# %%
# through the previous EDA we recall that it's best to eliminate top 1% and bottom 1% of players based on spm
upper = np.percentile(df.spm, 99)
lower = np.percentile(df.spm, 1)

df = df[(df['spm'] >= lower) & (df['spm'] <= upper)]

# %%
# Create arrays for features and target variable
y = df['spm'].values
X = df['kpm'].values

# Print the dimensions of X and y before reshaping
print("Dimensions of y before reshaping: {}".format(y.shape))
print("Dimensions of X before reshaping: {}".format(X.shape))

# Reshape X and y
y = y.reshape(-1,1)
X = X.reshape(-1,1)

# Print the dimensions of X and y after reshaping
print("Dimensions of y after reshaping: {}".format(y.shape))
print("Dimensions of X after reshaping: {}".format(X.shape))
# Out:
# Dimensions of y before reshaping: (37081,)
# Dimensions of X before reshaping: (37081,)
# Dimensions of y after reshaping: (37081, 1)
# Dimensions of X after reshaping: (37081, 1)

# %% [markdown]
# ### Linear Regression - Single Independent Variable for testing

# %%
# Create the regressor: reg
reg = LinearRegression()

# Create the prediction space
prediction_space = np.linspace(min(X), max(X)).reshape(-1,1)

# Fit the model to the data
reg.fit(X, y)

# Compute predictions over the prediction space: y_pred
y_pred = reg.predict(prediction_space)

# Print R^2 
print(reg.score(X, y))
# Out:
# 0.004903279484539835

# %%
# Plot regression line
_ = plt.figure(figsize=(8,5))
_ = sns.regplot('kpm', 'spm', data=df, fit_reg = True, scatter_kws={'alpha':0.3})

# %% [markdown]
# **Comment**: The R^2 and plot could signify that there are multiple factors that contribute to a high score per minute(spm). Kills per minute alone does not explain why a player is able to obtain a high score per minute(spm).

# %% [markdown]
# ### Create an Evaulaute Function for Hyperparameter Testing

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy

# %% [markdown]
# ### Feature Cleanup

# %%
# remove columns with duplicate values along with rankings, id, unlocks, medals
x_cols = df.drop(['player_id','time','ladder_rank','score','skill',
                  'battle_rank','scores.rankScore','extra.spm','extra.gspm',
                  'extra.medals','extra.ribbonsUnique','extra.medalsUnique',
                  'extra.ribbons','extra.ribpr','scores.unlock'],axis=1)
x_cols.shape
# Out:
# (37081, 247)

# %%
X = x_cols.drop(['spm'],axis = 1)
y = x_cols.spm

# %%
X = X.reset_index(drop=True)
y = y.reset_index(drop=True)

# %% [markdown]
# ### Train/Test Split

# %%
# Split data into training and testing data
from sklearn.model_selection import train_test_split
random.seed(100)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# default split is 75% for training and 25% for testing
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (27810, 246)
# (27810,)
# (9271, 246)
# (9271,)

# %% [markdown]
# ### Random Forest

# %%
#Import randomforest regressor model
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor(max_depth=4, random_state=0, n_estimators=100)

# %%
# %%time
regr.fit(X_train, y_train)
# Out:
# Wall time: 25.4 s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=4,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
# make predictions on the testing set
y_pred = np.array(regr.predict(X_test))

# %%
# calculate RMSE using scikit-learn
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 108.73854305468484

# %%
# calculate MAE using scikit-learn
print(metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 75.67440087275529

# %%
# calculate Rsquare using scikit-learn
print(metrics.r2_score(y_test, y_pred))

# calculate adjusted Rsquare
r_squared = metrics.r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(adjusted_r_squared)
# Out:
# 0.8016530021567668
# 0.7998827535818862

# %%
base_accuracy = evaluate(regr, X_test, y_test)
print(base_accuracy)
# Out:
# Model Performance
# Average Error: 75.6744 degrees.
# Accuracy = 77.90%.
# 77.90178583702445

# %% [markdown]
# ### Hyperparameter Tuning - Random Forest

# %%
# Grid Search with Cross Validation
# Look at parameters
regr.get_params()
# Out:
# {'bootstrap': True,
#  'criterion': 'mse',
#  'max_depth': 4,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 0,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import GridSearchCV

# Create the parameter grid based on the results of random search 
param_grid = {
    'bootstrap': [True],
    'max_depth': [5, 10],
    'min_samples_leaf': [1, 2],
    'min_samples_split': [2, 3],
    'n_estimators': [100, 200]
}

# Create a based model
rf = RandomForestRegressor()

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
# notes this may take a long time to finish running
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed: 23.9min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=RandomForestRegressor(bootstrap=True, criterion='mse',
#                                              max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators='warn', n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'bootstrap': [True], 'max_depth': [5, 10],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 3],
#                          'n_estimators': [100, 200]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 10,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 200}

# %%
best_grid = grid_search.best_estimator_
grid_accuracy = evaluate(best_grid, X_test, y_test)
# Out:
# Model Performance
# Average Error: 51.4744 degrees.
# Accuracy = 86.32%.

# %%
print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - base_accuracy) / base_accuracy))
# Out:
# Improvement of 10.81%.

# %%
regr = RandomForestRegressor(bootstrap = True, max_depth=10, random_state=0, 
                             n_estimators=200, min_samples_leaf = 2, min_samples_split = 2)

# %%
# %%time
regr.fit(X_train, y_train)
# Out:
# Wall time: 7min 5s
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=10,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=2, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=200,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
# make predictions on the testing set
y_pred = np.array(regr.predict(X_test))

# %%
# calculate RMSE using scikit-learn
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 81.3561415747356

# %%
# calculate MAE using scikit-learn
print(metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 51.432851118141464

# %%
# calculate Rsquare using scikit-learn
print(metrics.r2_score(y_test, y_pred))

# calculate adjusted Rsquare
r_squared = metrics.r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(adjusted_r_squared)
# Out:
# 0.8889702661662613
# 0.8879793248854464

# %% [markdown]
# ### Support Vector Machine

# %%
#Import support vector machine for regression model
from sklearn.svm import SVR
svmod = SVR(gamma = 'scale', C = 1.0, epsilon = 0.1)

# %%
# %%time
svmod.fit(X_test, y_test)
# Out:
# Wall time: 24.9 s
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# make predictions on the testing set
y_pred = np.array(svmod.predict(X_test))

# %%
# calculate RMSE using scikit-learn
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 222.07144584843473

# %%
# calculate MAE using scikit-learn
from sklearn import metrics
print(metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 152.48153417758687

# %%
# calculate Rsquare using scikit-learn
print(metrics.r2_score(y_test, y_pred))

# calculate adjusted Rsquare
r_squared = metrics.r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(adjusted_r_squared)
# Out:
# 0.17273613973917157
# 0.1653528030332918

# %% [markdown]
# ### Hyperparameter Tuning - SVM

# %%
# Grid Search with Cross Validation
# Look at parameters
svmod.get_params()
# Out:
# {'C': 1.0,
#  'cache_size': 200,
#  'coef0': 0.0,
#  'degree': 3,
#  'epsilon': 0.1,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10],
    'epsilon': [0.1],
    'gamma': ['scale']
}

# Create a based model
svr = SVR()

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = svr, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
# notes this may take a long time to finish running
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed: 10.0min remaining:  8.7min
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed: 18.1min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3,
#                            epsilon=0.1, gamma='auto_deprecated', kernel='rbf',
#                            max_iter=-1, shrinking=True, tol=0.001,
#                            verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10], 'epsilon': [0.1],
#                          'gamma': ['scale']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
grid_search.best_params_
# Out:
# {'C': 10, 'epsilon': 0.1, 'gamma': 'scale'}

# %%
best_grid = grid_search.best_estimator_
grid_accuracy = evaluate(best_grid, X_test, y_test)
base_accuracy = evaluate(svmod, X_test, y_test)
print(base_accuracy)
# Out:
# Model Performance
# Average Error: 131.2202 degrees.
# Accuracy = 66.05%.
# Model Performance
# Average Error: 152.4815 degrees.
# Accuracy = 58.87%.
# 58.86602320351347

# %%
print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - base_accuracy) / base_accuracy))
# Out:
# Improvement of 12.20%.

# %%
svmod = SVR(gamma = 'scale', C = 10, epsilon = 0.1)

# %%
# %%time
svmod.fit(X_train, y_train)
# Out:
# Wall time: 4min 23s
# SVR(C=10, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
# make predictions on the testing set
y_pred = np.array(svmod.predict(X_test))

# %%
# calculate RMSE using scikit-learn
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 200.89798011112077

# %%
# calculate MAE using scikit-learn
print(metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 131.2202110814529

# %%
# calculate Rsquare using scikit-learn
print(metrics.r2_score(y_test, y_pred))

# calculate adjusted Rsquare
r_squared = metrics.r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(adjusted_r_squared)
# Out:
# 0.3229671328663485
# 0.3169246090004819

# %% [markdown]
# ### Lasso Regression

# %%
#Import linear model and load lasso
from sklearn import linear_model
lsr = linear_model.Lasso(alpha= 4, tol = 1)

# %%
# %%time
lsr.fit(X_test, y_test)
# Out:
# Wall time: 70.8 ms
# Lasso(alpha=4, copy_X=True, fit_intercept=True, max_iter=1000, normalize=False,
#       positive=False, precompute=False, random_state=None, selection='cyclic',
#       tol=1, warm_start=False)

# %%
# make predictions on the testing set
y_pred = np.array(lsr.predict(X_test))

# %%
# calculate RMSE using scikit-learn
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 124.07923256912454

# %%
# calculate MAE using scikit-learn
from sklearn import metrics
print(metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 80.06656670494704

# %%
# calculate Rsquare using scikit-learn
print(metrics.r2_score(y_test, y_pred))

# calculate adjusted Rsquare
r_squared = metrics.r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(adjusted_r_squared)
# Out:
# 0.7417402006316467
# 0.7394352298140792

# %% [markdown]
# ### Hyperparameter Tuning - Lasso

# %%
# Grid Search with Cross Validation
# Look at parameters
lsr.get_params()
# Out:
# {'alpha': 4,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 1000,
#  'normalize': False,
#  'positive': False,
#  'precompute': False,
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 1,
#  'warm_start': False}

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'alpha': [5, 4, 3, 2, 1],
    'tol': [1]
}

# Create a based model
lsr_base = linear_model.Lasso()

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = lsr_base, param_grid = param_grid, 
                          cv = 3, n_jobs = -1, verbose = 2)

# %%
# notes this may take a long time to finish running
grid_search.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  15 | elapsed:    0.7s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  15 out of  15 | elapsed:    1.3s finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#              estimator=Lasso(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=1000, normalize=False, positive=False,
#                              precompute=False, random_state=None,
#                              selection='cyclic', tol=0.0001, warm_start=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'alpha': [5, 4, 3, 2, 1], 'tol': [1]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
grid_search.best_params_
# Out:
# {'alpha': 3, 'tol': 1}

# %%
best_grid = grid_search.best_estimator_
grid_accuracy = evaluate(best_grid, X_test, y_test)
base_accuracy = evaluate(lsr, X_test, y_test)
print(base_accuracy)
# Out:
# Model Performance
# Average Error: 402.6419 degrees.
# Accuracy = 48.18%.
# Model Performance
# Average Error: 80.0666 degrees.
# Accuracy = 76.56%.
# 76.55737636705908

# %%
print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - base_accuracy) / base_accuracy))
# Out:
# Improvement of -37.06%.

# %%
# test accuracy on training data
grid_accuracy = evaluate(best_grid, X_train, y_train)
print(grid_accuracy)
# Out:
# Model Performance
# Average Error: 74.8517 degrees.
# Accuracy = 78.45%.
# 78.45464223039201

# %% [markdown]
# **Comment**: Based on the training data, the model has indeed improved by 2% in accuracy, however, using the testing data, we can see the model is thrown off and drops in accuracy by 37%. It's best to keep alpha = 4 as the parameter for lasso.

# %% [markdown]
# ### Ridge Regression

# %%
#Import linear model and load ridge
from sklearn.linear_model import Ridge

# %%
rg = Ridge(alpha=0.5)

# %%
# %%time
rg.fit(X_test, y_test)
# Out:
# Wall time: 175 ms
# Ridge(alpha=0.5, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
# make predictions on the testing set
y_pred = np.array(rg.predict(X_test))

# %%
# calculate RMSE using scikit-learn
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 111.82514466950511

# %%
# calculate MAE using scikit-learn
from sklearn import metrics
print(metrics.mean_absolute_error(y_test, y_pred))
# Out:
# 72.69792575740283

# %%
# calculate Rsquare using scikit-learn
print(metrics.r2_score(y_test, y_pred))

# calculate adjusted Rsquare
r_squared = metrics.r2_score(y_test, y_pred)
adjusted_r_squared = 1 - (1-r_squared)*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1)
print(adjusted_r_squared)
# Out:
# 0.790232815419692
# 0.7883606415849587

# %% [markdown]
# ### Hyperparameter Tuning - Ridge

# %%
# Grid Search with Cross Validation
# Look at parameters
rg.get_params()
# Out:
# {'alpha': 0.5,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'normalize': False,
#  'random_state': None,
#  'solver': 'auto',
#  'tol': 0.001}

# %%
# Create the parameter grid based on the results of random search 
param_grid = {
    'alpha': [0.005, 0.05, 0.5, 5, 50, 500, 5000]
}

# Create a based model
rg_base = Ridge()

# Instantiate the grid search model
grid_search = GridSearchCV(estimator = rg_base, param_grid = param_grid, 
                          cv = 5, n_jobs = -1, verbose = 2)

# %%
# notes this may take a long time to finish running
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:   14.7s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=Ridge(alpha=1.0, copy_X=True, fit_intercept=True,
#                              max_iter=None, normalize=False, random_state=None,
#                              solver='auto', tol=0.001),
#              iid='warn', n_jobs=-1,
#              param_grid={'alpha': [0.005, 0.05, 0.5, 5, 50, 500, 5000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
grid_search.best_params_
# Out:
# {'alpha': 0.005}

# %%
best_grid = grid_search.best_estimator_
grid_accuracy = evaluate(best_grid, X_test, y_test)
base_accuracy = evaluate(rg, X_test, y_test)
print(base_accuracy)
# Out:
# Model Performance
# Average Error: 199.8905 degrees.
# Accuracy = 67.61%.
# Model Performance
# Average Error: 72.6979 degrees.
# Accuracy = 78.37%.
# 78.3747556684148

# %%
print('Improvement of {:0.2f}%.'.format( 100 * (grid_accuracy - base_accuracy) / base_accuracy))
# Out:
# Improvement of -13.74%.

# %%
# test accuracy on training data
grid_accuracy = evaluate(best_grid, X_train, y_train)
print(grid_accuracy)
# Out:
# Model Performance
# Average Error: 68.1395 degrees.
# Accuracy = 79.89%.
# 79.8911665576546

# %% [markdown]
# **comment**: The ridge regression seems to suffer the same issue with lasso, where the model improves ny 1% using the training data, but drops in accuracy based on the test data. Hence it's best to keep alpha = 0.5 as the parameter for ridge for now.

# %% [markdown]
# ### Table - Default Models

# %% [markdown]
# |Original  | Random Forest | Support Vector Machine | Lasso Regression | Ridge Regression |
# |----------|---------------|------------------------|------------------|------------------|
# | RMSE     | 108.73        | 222.05                 | 124.07           | 111.82           |
# | MAE      | 75.67         | 152.48                 | 80.06            | 72.69            |
# | R^2 adj. | 0.799         | 0.165                  | 0.739            | 0.788            |

# %% [markdown]
# ### Table - Hyperparameter Adjusted Models

# %% [markdown]
# |Hyper Adj.| Random Forest | Support Vector Machine | Lasso Regression | Ridge Regression |
# |----------|---------------|------------------------|------------------|------------------|
# | RMSE     | 81.35         | 200.89                 | N/A              | N/A              |
# | MAE      | 51.43         | 131.22                 | N/A              | N/A              |
# | R^2 adj. | 0.887         | 0.316                  | N/A              | N/A              |

# %% [markdown]
# ### Reading feature importances for Random Forest

# %%
list_of_tuples = list(zip(X.columns, regr.feature_importances_))
df = pd.DataFrame(list_of_tuples, columns = ['Features', 'Importance'])

# %%
df.sort_values(by='Importance', ascending=False).head(10)
# Out:
#                         Features  Importance
# 29              kits.assault.spm    0.678236
# 58                  scores.award    0.068048
# 36             kits.engineer.spm    0.067571
# 44              kits.support.spm    0.016708
# 164     ASSAULT RIFLE_stat.score    0.014352
# 28            kits.assault.score    0.013097
# 218  Main Battle Tanks_extra.spm    0.011637
# 183            SIDEARM_extra.spm    0.008457
# 17                extra.weaTimeP    0.008365
# 70                    timePlayed    0.008048

# %% [markdown]
# **comments:** based on the feature importance generated through the random forest regressor, we can see that features
# such as assault kit, engineering kit, support kit, battle tank spm, assault rifle score contributes greatly to the
# prediction of an spm score. Though whether the feature positively or negatively affected the final spm is unknown.

# %%
random.seed(1)
print(random.randint(0,9271))
print(random.randint(0,9271))
# Out:
# 2201
# 1033

# %%
instance = X_test.iloc[[2201,1103],:]

# %%
np.array(regr.predict(instance))
# Out:
# array([346.55207813, 215.15548086])

# %%
instance['kits.assault.spm']
# Out:
# 19200    480
# 34689    266
# Name: kits.assault.spm, dtype: int64

# %%
from treeinterpreter import treeinterpreter as ti

# %%
prediction, bias, contributions = ti.predict(regr, instance)

# %%
# using treeinterpreter, we can try to understand the contributions of the features, however, the results are still
# unclear
for i in range(len(instance)):
    print ("Instance", i)
    print ("Bias", bias[i])
    print ("Feature contributions:")
    for c, feature in sorted(zip(contributions[i], 
                                 X_test.columns), 
                             key=lambda x: -abs(x[0])):
        print (feature, round(c, 2))
    print ("-"*20)
# Out:
# Instance 0
# Bias 407.95495202804784
# Feature contributions:
# scores.award 51.94
# kits.engineer.spm -42.47
# extra.kdr -17.98
# kits.support.spm -17.54
# Main Battle Tanks_extra.spm -11.77
# kits.assault.spm -11.38
# extra.weaTimeP -10.87
# kits.recon.spm -5.02
# SIDEARM_extra.spm -4.82
# minutes 1.77
# Air Jet Stealth_stat.time 1.76
# kpm -1.64
# kits.assault.score 1.27
# Air Jet Attack_stat.score 1.09
# Air Helicopter Attack_extra.spm -1.03
# LMG_extra.sfpm 0.9
# ASSAULT RIFLE_stat.score 0.87
# timePlayed -0.81
# extra.accuracy 0.76
# Mobile Artillery_stat.time -0.74
# SNIPER RIFLE_extra.spm -0.74
# Air Jet Stealth_stat.score 0.74
# kits.recon.time 0.63
# Air Helicopter Scout_stat.time 0.63
# SNIPER RIFLE_stat.kills 0.52
# Air Jet Attack_stat.time 0.51
# LMG_extra.spm -0.49
# SHOTGUN_stat.score 0.49
# Air Jet Stealth_extra.spm 0.46
# DMR_extra.sfpm 0.44
# numRounds -0.43
# ASSAULT RIFLE_stat.time 0.42
# Air Jet Attack_extra.spm 0.41
# extra.vehTimeP -0.4
# SIDEARM_stat.hits 0.38
# GADGET_stat.kills 0.36
# SNIPER RIFLE_stat.shots 0.35
# SIDEARM_stat.hs 0.35
# SNIPER RIFLE_stat.hits 0.32
# suppressionAssists 0.32
# SNIPER RIFLE_extra.hkp 0.31
# Transport_stat.time 0.27
# GADGET_stat.time 0.26
# extra.roundsFinished -0.26
# Air Helicopter Attack_stat.time 0.23
# ASSAULT RIFLE_stat.shots -0.23
# scores.general -0.23
# SHOTGUN_extra.accuracy 0.22
# kits.assault.time 0.2
# vehicleDamage -0.18
# Boat_stat.time -0.17
# Main Battle Tanks_stat.score -0.17
# longestHeadshot 0.17
# scores.team -0.16
# scores.squad -0.14
# PDW_stat.shots -0.13
# PDW_stat.time -0.13
# extra.vehicleTime -0.12
# ASSAULT RIFLE_stat.hits 0.11
# LMG_stat.hs 0.1
# SNIPER RIFLE_stat.hs 0.1
# Weapon Stationary _stat.time -0.1
# numLosses -0.08
# extra.weaKpm -0.08
# deaths -0.08
# extra.vehicleKills -0.07
# numWins -0.07
# LMG_stat.score -0.06
# BATTLE PICKUP_extra.accuracy -0.06
# Main Battle Tanks_stat.time -0.06
# Main Battle Tanks_stat.kills -0.06
# revives -0.06
# heals 0.05
# GRENADE_stat.score 0.05
# GRENADE_extra.spm 0.05
# PDW_stat.score -0.05
# kits.engineer.score -0.04
# extra.weaKillsP -0.04
# GADGET_stat.hits -0.04
# kits.support.time -0.03
# SIDEARM_stat.time -0.03
# extra.hkp -0.03
# BATTLE PICKUP_stat.time -0.02
# GADGET_stat.shots -0.02
# extra.weaponTime -0.02
# nemesisKills -0.02
# SNIPER RIFLE_extra.accuracy -0.02
# shotsHit -0.01
# avengerKills -0.01
# shotsFired -0.01
# dogtagsTaken 0.0
# extra.assignments 0.0
# extra.khp 0.0
# extra.sfpm 0.0
# extra.unknownKills 0.0
# extra.vehKillsP 0.0
# extra.weaponKills 0.0
# extra.wlr 0.0
# flagCaptures 0.0
# flagDefend 0.0
# headshots 0.0
# killAssists 0.0
# killStreakBonus 0.0
# kills 0.0
# kits.assault.stars 0.0
# kits.commander.score 0.0
# kits.commander.spm 0.0
# kits.commander.time 0.0
# kits.engineer.stars 0.0
# kits.engineer.time 0.0
# kits.recon.score 0.0
# kits.recon.stars 0.0
# kits.support.score 0.0
# kits.support.stars 0.0
# mcomDefendKills 0.0
# nemesisStreak 0.0
# repairs 0.0
# resupplies 0.0
# saviorKills 0.0
# scores.bonus 0.0
# scores.combatScore 0.0
# scores.score 0.0
# scores.totalScore 0.0
# scores.vehicle 0.0
# vehiclesDestroyed 0.0
# Conquest_score 0.0
# Rush_score 0.0
# Deathmatch_score 0.0
# Domination_score 0.0
# Obliteration_score 0.0
# GADGET_extra.accuracy 0.0
# GADGET_extra.sfpm 0.0
# GADGET_stat.hs 0.0
# SNIPER RIFLE_extra.sfpm 0.0
# SNIPER RIFLE_stat.score 0.0
# SNIPER RIFLE_stat.time 0.0
# PDW_extra.accuracy 0.0
# PDW_extra.hkp 0.0
# PDW_extra.kpm 0.0
# PDW_extra.sfpm 0.0
# PDW_extra.spm 0.0
# PDW_stat.hits 0.0
# PDW_stat.hs 0.0
# PDW_stat.kills 0.0
# CARBINE_extra.accuracy 0.0
# CARBINE_extra.hkp 0.0
# CARBINE_extra.kpm 0.0
# CARBINE_extra.sfpm 0.0
# CARBINE_extra.spm 0.0
# CARBINE_stat.hits 0.0
# CARBINE_stat.hs 0.0
# CARBINE_stat.kills 0.0
# CARBINE_stat.score 0.0
# CARBINE_stat.shots 0.0
# CARBINE_stat.time 0.0
# BATTLE PICKUP_extra.hkp 0.0
# BATTLE PICKUP_extra.sfpm 0.0
# BATTLE PICKUP_stat.hits 0.0
# BATTLE PICKUP_stat.hs 0.0
# BATTLE PICKUP_stat.kills 0.0
# BATTLE PICKUP_stat.shots 0.0
# LMG_extra.accuracy 0.0
# LMG_extra.hkp 0.0
# LMG_extra.kpm 0.0
# LMG_stat.hits 0.0
# LMG_stat.kills 0.0
# LMG_stat.shots 0.0
# LMG_stat.time 0.0
# GRENADE_extra.accuracy 0.0
# GRENADE_extra.kpm 0.0
# GRENADE_extra.sfpm 0.0
# GRENADE_stat.hits 0.0
# GRENADE_stat.kills 0.0
# GRENADE_stat.shots 0.0
# GRENADE_stat.time 0.0
# DMR_extra.accuracy 0.0
# DMR_extra.hkp 0.0
# DMR_extra.kpm 0.0
# DMR_extra.spm 0.0
# DMR_stat.hits 0.0
# DMR_stat.hs 0.0
# DMR_stat.kills 0.0
# DMR_stat.score 0.0
# DMR_stat.shots 0.0
# DMR_stat.time 0.0
# ASSAULT RIFLE_extra.accuracy 0.0
# ASSAULT RIFLE_extra.hkp 0.0
# ASSAULT RIFLE_extra.kpm 0.0
# ASSAULT RIFLE_extra.sfpm 0.0
# ASSAULT RIFLE_extra.spm 0.0
# ASSAULT RIFLE_stat.hs 0.0
# ASSAULT RIFLE_stat.kills 0.0
# KNIFE_stat.kills 0.0
# SHOTGUN_extra.hkp 0.0
# SHOTGUN_extra.kpm 0.0
# SHOTGUN_extra.sfpm 0.0
# SHOTGUN_extra.spm 0.0
# SHOTGUN_stat.hits 0.0
# SHOTGUN_stat.hs 0.0
# SHOTGUN_stat.kills 0.0
# SHOTGUN_stat.shots 0.0
# SHOTGUN_stat.time 0.0
# SIDEARM_extra.accuracy 0.0
# SIDEARM_extra.hkp 0.0
# SIDEARM_extra.kpm 0.0
# SIDEARM_extra.sfpm 0.0
# SIDEARM_stat.kills 0.0
# SIDEARM_stat.score 0.0
# SIDEARM_stat.shots 0.0
# Infantry Fighting Vehicle_stat.destroys 0.0
# Infantry Fighting Vehicle_stat.kills 0.0
# Infantry Fighting Vehicle_stat.time 0.0
# Anti Air_stat.destroys 0.0
# Anti Air_stat.kills 0.0
# Anti Air_stat.time 0.0
# Transport_stat.destroys 0.0
# Transport_stat.kills 0.0
# Air Jet Stealth_stat.destroys 0.0
# Air Jet Stealth_stat.kills 0.0
# Air Helicopter Scout AH6_stat.score 0.0
# Air Jet Attack_stat.destroys 0.0
# Air Jet Attack_stat.kills 0.0
# Weapon Stationary _stat.destroys 0.0
# Weapon Stationary _stat.kills 0.0
# Boat_stat.destroys 0.0
# Boat_stat.kills 0.0
# Air_stat.kills 0.0
# Air_stat.time 0.0
# Main Battle Tanks_stat.destroys 0.0
# Air Helicopter Scout_stat.destroys 0.0
# Air Helicopter Scout_stat.kills 0.0
# Air Helicopter Attack_stat.destroys 0.0
# Air Helicopter Attack_stat.kills 0.0
# Air Helicopter Attack_stat.score 0.0
# Mobile Artillery_stat.destroys 0.0
# Mobile Artillery_stat.kills 0.0
# Transport UH-1Y Venom_stat.time 0.0
# Soldier Equiment_stat.destroys 0.0
# Soldier Equiment_stat.kills 0.0
# Fast Attack Craft_extra.spm 0.0
# Fast Attack Craft_stat.destroys 0.0
# Fast Attack Craft_stat.kills 0.0
# Fast Attack Craft_stat.score 0.0
# Fast Attack Craft_stat.time 0.0
# IFV BTR 90_stat.score 0.0
# AA LAV-AD_stat.score 0.0
# --------------------
# Instance 1
# Bias 407.95495202804784
# Feature contributions:
# kits.assault.spm -143.69
# kits.engineer.spm -24.41
# kits.support.spm -12.26
# scores.award 7.98
# minutes -4.28
# kits.recon.spm -4.23
# numRounds -3.71
# timePlayed -2.1
# extra.weaTimeP -1.72
# scores.team -1.54
# PDW_extra.sfpm 1.37
# SIDEARM_stat.time 1.24
# extra.kdr -1.11
# deaths -0.7
# extra.weaponTime -0.69
# Conquest_score 0.68
# Main Battle Tanks_extra.spm -0.67
# kpm -0.63
# numLosses -0.57
# nemesisKills -0.42
# ASSAULT RIFLE_stat.hits -0.42
# ASSAULT RIFLE_stat.score -0.42
# kits.recon.time -0.34
# ASSAULT RIFLE_stat.shots 0.33
# killStreakBonus -0.31
# kits.engineer.time 0.31
# SIDEARM_extra.spm 0.28
# Transport_stat.time 0.27
# kits.assault.score -0.2
# ASSAULT RIFLE_stat.kills -0.19
# kits.recon.score -0.15
# kits.support.time -0.14
# kits.support.score -0.13
# ASSAULT RIFLE_stat.hs -0.12
# heals -0.12
# PDW_stat.time 0.11
# extra.sfpm 0.1
# SIDEARM_stat.score -0.09
# PDW_stat.hits 0.08
# revives -0.08
# Air_stat.time 0.08
# kits.assault.time -0.07
# SIDEARM_stat.kills 0.07
# ASSAULT RIFLE_extra.spm 0.06
# ASSAULT RIFLE_stat.time -0.06
# kits.assault.stars -0.06
# flagDefend -0.06
# SNIPER RIFLE_stat.shots -0.04
# saviorKills 0.04
# Deathmatch_score -0.04
# ASSAULT RIFLE_extra.hkp -0.04
# scores.score 0.03
# GRENADE_stat.shots 0.03
# extra.roundsFinished -0.03
# scores.combatScore 0.03
# extra.accuracy 0.03
# LMG_extra.sfpm -0.02
# extra.weaKillsP -0.02
# GRENADE_extra.spm -0.01
# kits.engineer.score 0.01
# shotsFired -0.01
# shotsHit -0.01
# extra.weaponKills -0.01
# BATTLE PICKUP_extra.hkp -0.01
# extra.vehTimeP -0.01
# longestHeadshot -0.01
# GRENADE_extra.kpm -0.0
# avengerKills 0.0
# dogtagsTaken 0.0
# extra.assignments 0.0
# extra.hkp 0.0
# extra.khp 0.0
# extra.unknownKills 0.0
# extra.vehKillsP 0.0
# extra.vehicleKills 0.0
# extra.vehicleTime 0.0
# extra.weaKpm 0.0
# extra.wlr 0.0
# flagCaptures 0.0
# headshots 0.0
# killAssists 0.0
# kills 0.0
# kits.commander.score 0.0
# kits.commander.spm 0.0
# kits.commander.time 0.0
# kits.engineer.stars 0.0
# kits.recon.stars 0.0
# kits.support.stars 0.0
# mcomDefendKills 0.0
# nemesisStreak 0.0
# numWins 0.0
# repairs 0.0
# resupplies 0.0
# scores.bonus 0.0
# scores.general 0.0
# scores.squad 0.0
# scores.totalScore 0.0
# scores.vehicle 0.0
# suppressionAssists 0.0
# vehicleDamage 0.0
# vehiclesDestroyed 0.0
# Rush_score 0.0
# Domination_score 0.0
# Obliteration_score 0.0
# GADGET_extra.accuracy 0.0
# GADGET_extra.sfpm 0.0
# GADGET_stat.hits 0.0
# GADGET_stat.hs 0.0
# GADGET_stat.kills 0.0
# GADGET_stat.shots 0.0
# GADGET_stat.time 0.0
# SNIPER RIFLE_extra.accuracy 0.0
# SNIPER RIFLE_extra.hkp 0.0
# SNIPER RIFLE_extra.sfpm 0.0
# SNIPER RIFLE_extra.spm 0.0
# SNIPER RIFLE_stat.hits 0.0
# SNIPER RIFLE_stat.hs 0.0
# SNIPER RIFLE_stat.kills 0.0
# SNIPER RIFLE_stat.score 0.0
# SNIPER RIFLE_stat.time 0.0
# PDW_extra.accuracy 0.0
# PDW_extra.hkp 0.0
# PDW_extra.kpm 0.0
# PDW_extra.spm 0.0
# PDW_stat.hs 0.0
# PDW_stat.kills 0.0
# PDW_stat.score 0.0
# PDW_stat.shots 0.0
# CARBINE_extra.accuracy 0.0
# CARBINE_extra.hkp 0.0
# CARBINE_extra.kpm 0.0
# CARBINE_extra.sfpm 0.0
# CARBINE_extra.spm 0.0
# CARBINE_stat.hits 0.0
# CARBINE_stat.hs 0.0
# CARBINE_stat.kills 0.0
# CARBINE_stat.score 0.0
# CARBINE_stat.shots 0.0
# CARBINE_stat.time 0.0
# BATTLE PICKUP_extra.accuracy 0.0
# BATTLE PICKUP_extra.sfpm 0.0
# BATTLE PICKUP_stat.hits 0.0
# BATTLE PICKUP_stat.hs 0.0
# BATTLE PICKUP_stat.kills 0.0
# BATTLE PICKUP_stat.shots 0.0
# BATTLE PICKUP_stat.time 0.0
# LMG_extra.accuracy 0.0
# LMG_extra.hkp 0.0
# LMG_extra.kpm 0.0
# LMG_extra.spm 0.0
# LMG_stat.hits 0.0
# LMG_stat.hs 0.0
# LMG_stat.kills 0.0
# LMG_stat.score 0.0
# LMG_stat.shots 0.0
# LMG_stat.time 0.0
# GRENADE_extra.accuracy 0.0
# GRENADE_extra.sfpm 0.0
# GRENADE_stat.hits 0.0
# GRENADE_stat.kills 0.0
# GRENADE_stat.score 0.0
# GRENADE_stat.time 0.0
# DMR_extra.accuracy 0.0
# DMR_extra.hkp 0.0
# DMR_extra.kpm 0.0
# DMR_extra.sfpm 0.0
# DMR_extra.spm 0.0
# DMR_stat.hits 0.0
# DMR_stat.hs 0.0
# DMR_stat.kills 0.0
# DMR_stat.score 0.0
# DMR_stat.shots 0.0
# DMR_stat.time 0.0
# ASSAULT RIFLE_extra.accuracy 0.0
# ASSAULT RIFLE_extra.kpm 0.0
# ASSAULT RIFLE_extra.sfpm 0.0
# KNIFE_stat.kills 0.0
# SHOTGUN_extra.accuracy 0.0
# SHOTGUN_extra.hkp 0.0
# SHOTGUN_extra.kpm 0.0
# SHOTGUN_extra.sfpm 0.0
# SHOTGUN_extra.spm 0.0
# SHOTGUN_stat.hits 0.0
# SHOTGUN_stat.hs 0.0
# SHOTGUN_stat.kills 0.0
# SHOTGUN_stat.score 0.0
# SHOTGUN_stat.shots 0.0
# SHOTGUN_stat.time 0.0
# SIDEARM_extra.accuracy 0.0
# SIDEARM_extra.hkp 0.0
# SIDEARM_extra.kpm 0.0
# SIDEARM_extra.sfpm 0.0
# SIDEARM_stat.hits 0.0
# SIDEARM_stat.hs 0.0
# SIDEARM_stat.shots 0.0
# Infantry Fighting Vehicle_stat.destroys 0.0
# Infantry Fighting Vehicle_stat.kills 0.0
# Infantry Fighting Vehicle_stat.time 0.0
# Anti Air_stat.destroys 0.0
# Anti Air_stat.kills 0.0
# Anti Air_stat.time 0.0
# Transport_stat.destroys 0.0
# Transport_stat.kills 0.0
# Air Jet Stealth_extra.spm 0.0
# Air Jet Stealth_stat.destroys 0.0
# Air Jet Stealth_stat.kills 0.0
# Air Jet Stealth_stat.score 0.0
# Air Jet Stealth_stat.time 0.0
# Air Helicopter Scout AH6_stat.score 0.0
# Air Jet Attack_extra.spm 0.0
# Air Jet Attack_stat.destroys 0.0
# Air Jet Attack_stat.kills 0.0
# Air Jet Attack_stat.score 0.0
# Air Jet Attack_stat.time 0.0
# Weapon Stationary _stat.destroys 0.0
# Weapon Stationary _stat.kills 0.0
# Weapon Stationary _stat.time 0.0
# Boat_stat.destroys 0.0
# Boat_stat.kills 0.0
# Boat_stat.time 0.0
# Air_stat.kills 0.0
# Main Battle Tanks_stat.destroys 0.0
# Main Battle Tanks_stat.kills 0.0
# Main Battle Tanks_stat.score 0.0
# Main Battle Tanks_stat.time 0.0
# Air Helicopter Scout_stat.destroys 0.0
# Air Helicopter Scout_stat.kills 0.0
# Air Helicopter Scout_stat.time 0.0
# Air Helicopter Attack_extra.spm 0.0
# Air Helicopter Attack_stat.destroys 0.0
# Air Helicopter Attack_stat.kills 0.0
# Air Helicopter Attack_stat.score 0.0
# Air Helicopter Attack_stat.time 0.0
# Mobile Artillery_stat.destroys 0.0
# Mobile Artillery_stat.kills 0.0
# Mobile Artillery_stat.time 0.0
# Transport UH-1Y Venom_stat.time 0.0
# Soldier Equiment_stat.destroys 0.0
# Soldier Equiment_stat.kills 0.0
# Fast Attack Craft_extra.spm 0.0
# Fast Attack Craft_stat.destroys 0.0
# Fast Attack Craft_stat.kills 0.0
# Fast Attack Craft_stat.score 0.0
# Fast Attack Craft_stat.time 0.0
# IFV BTR 90_stat.score 0.0
# AA LAV-AD_stat.score 0.0
# --------------------
