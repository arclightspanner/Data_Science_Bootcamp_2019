# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
# import the data
df = pd.read_csv("collected data9.6.2019/merged_data.csv", index_col=0)

# %%
# calculate total minutes of play time for each player by reversing formula spm * minutes = score
df['minutes'] = df['score']/df['spm']
df['kpm'] = df['kills']/df['minutes']

# %%
# through the previous EDA we recall that it's best to eliminate top 1% and bottom 1% of players based on spm
upper = np.percentile(df.spm, 99)
lower = np.percentile(df.spm, 1)

df = df[(df['spm'] >= lower) & (df['spm'] <= upper)]

# %%
# Create arrays for features and target variable
y = df['spm'].values
X = df['kpm'].values

# Print the dimensions of X and y before reshaping
print("Dimensions of y before reshaping: {}".format(y.shape))
print("Dimensions of X before reshaping: {}".format(X.shape))

# Reshape X and y
y = y.reshape(-1,1)
X = X.reshape(-1,1)

# Print the dimensions of X and y after reshaping
print("Dimensions of y after reshaping: {}".format(y.shape))
print("Dimensions of X after reshaping: {}".format(X.shape))
# Out:
# Dimensions of y before reshaping: (37081,)
# Dimensions of X before reshaping: (37081,)
# Dimensions of y after reshaping: (37081, 1)
# Dimensions of X after reshaping: (37081, 1)

# %%
# Create the regressor: reg
reg = LinearRegression()

# Create the prediction space
prediction_space = np.linspace(min(X), max(X)).reshape(-1,1)

# Fit the model to the data
reg.fit(X, y)

# Compute predictions over the prediction space: y_pred
y_pred = reg.predict(prediction_space)

# Print R^2 
print(reg.score(X, y))
# Out:
# 0.004903279484539835

# %%
# Plot regression line
_ = plt.figure(figsize=(8,5))
_ = sns.regplot('kpm', 'spm', data=df, fit_reg = True, scatter_kws={'alpha':0.3})

# %% [markdown]
# **Conclusion**: The R^2 and plot could signify that there are multiple factors that contribute to a high score per minute(spm). Kills per minute alone does not explain why a player is able to obtain a high score per minute(spm).

# %% [markdown]
# <hr>

# %%
# remove columns with duplicate values along with rankings, id, unlocks, medals
x_cols = df.drop(['player_id','time','ladder_rank','score','skill',
                  'battle_rank','scores.rankScore','extra.spm','extra.gspm',
                  'extra.medals','extra.ribbonsUnique','extra.medalsUnique',
                  'extra.ribbons','extra.ribpr','scores.unlock'],axis=1)
x_cols.shape
# Out:
# (37081, 247)

# %%
import statsmodels.api as sm

X = x_cols.drop(['spm'],axis = 1)
y = x_cols.spm

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    spm   R-squared (uncentered):                   0.943
# Model:                            OLS   Adj. R-squared (uncentered):              0.942
# Method:                 Least Squares   F-statistic:                              2502.
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):                        0.00
# Time:                        16:30:42   Log-Likelihood:                     -2.2826e+05
# No. Observations:               37081   AIC:                                  4.570e+05
# Df Residuals:                   36839   BIC:                                  4.591e+05
# Df Model:                         242
# Covariance Type:            nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Obliteration_score                      -3.677e-06   8.57e-06     -0.429      0.668   -2.05e-05    1.31e-05
# GADGET_extra.accuracy                      -0.1245      0.044     -2.860      0.004      -0.210      -0.039
# GADGET_extra.sfpm                           0.0957      0.023      4.114      0.000       0.050       0.141
# GADGET_stat.hits                        -6.694e-05   7.59e-05     -0.882      0.378      -0.000    8.18e-05
# GADGET_stat.hs                              0.0785      0.067      1.176      0.240      -0.052       0.209
# GADGET_stat.kills                          -0.3815      0.317     -1.205      0.228      -1.002       0.239
# GADGET_stat.shots                        -1.72e-05   4.84e-05     -0.355      0.722      -0.000    7.76e-05
# GADGET_stat.time                            0.0042      0.008      0.541      0.588      -0.011       0.020
# SNIPER RIFLE_extra.accuracy                -0.4839      0.061     -7.894      0.000      -0.604      -0.364
# SNIPER RIFLE_extra.hkp                      0.0960      0.032      3.047      0.002       0.034       0.158
# SNIPER RIFLE_extra.sfpm                    -0.2039      0.391     -0.521      0.603      -0.971       0.563
# SNIPER RIFLE_extra.spm                  -8.417e-05      0.000     -0.475      0.634      -0.000       0.000
# SNIPER RIFLE_stat.hits                     -0.0006      0.001     -0.514      0.607      -0.003       0.002
# SNIPER RIFLE_stat.hs                        0.0183      0.008      2.401      0.016       0.003       0.033
# SNIPER RIFLE_stat.kills                    -0.3798      0.317     -1.200      0.230      -1.000       0.241
# SNIPER RIFLE_stat.score                 -6.796e-05   1.69e-05     -4.013      0.000      -0.000   -3.48e-05
# SNIPER RIFLE_stat.shots                     0.0004      0.000      2.229      0.026    4.84e-05       0.001
# SNIPER RIFLE_stat.time                      0.0042      0.008      0.539      0.590      -0.011       0.019
# PDW_extra.accuracy                         -0.8535      0.154     -5.543      0.000      -1.155      -0.552
# PDW_extra.hkp                              -0.1412      0.044     -3.218      0.001      -0.227      -0.055
# PDW_extra.kpm                             -17.6267      1.694    -10.404      0.000     -20.947     -14.306
# PDW_extra.sfpm                             -0.2793      0.031     -9.067      0.000      -0.340      -0.219
# PDW_extra.spm                               0.2268      0.013     17.981      0.000       0.202       0.252
# PDW_stat.hits                              -0.0006      0.000     -1.865      0.062      -0.001    2.88e-05
# PDW_stat.hs                                 0.0220      0.015      1.461      0.144      -0.008       0.051
# PDW_stat.kills                             -0.3797      0.317     -1.199      0.230      -1.000       0.241
# PDW_stat.score                          -6.637e-05   1.49e-05     -4.443      0.000   -9.56e-05   -3.71e-05
# PDW_stat.shots                           8.988e-05   4.03e-05      2.228      0.026    1.08e-05       0.000
# PDW_stat.time                               0.0042      0.008      0.543      0.587      -0.011       0.020
# CARBINE_extra.accuracy                      0.1075      0.051      2.093      0.036       0.007       0.208
# CARBINE_extra.hkp                          -0.1400      0.050     -2.817      0.005      -0.237      -0.043
# CARBINE_extra.kpm                         -25.5600      1.734    -14.744      0.000     -28.958     -22.162
# CARBINE_extra.sfpm                         -0.1663      0.029     -5.822      0.000      -0.222      -0.110
# CARBINE_extra.spm                           0.2891      0.012     23.713      0.000       0.265       0.313
# CARBINE_stat.hits                          -0.0002      0.000     -1.594      0.111      -0.000    4.34e-05
# CARBINE_stat.hs                             0.0229      0.010      2.382      0.017       0.004       0.042
# CARBINE_stat.kills                         -0.3794      0.317     -1.198      0.231      -1.000       0.241
# CARBINE_stat.score                      -6.526e-05   9.37e-06     -6.963      0.000   -8.36e-05   -4.69e-05
# CARBINE_stat.shots                       1.878e-05   1.44e-05      1.303      0.193   -9.47e-06     4.7e-05
# CARBINE_stat.time                           0.0042      0.008      0.542      0.588      -0.011       0.020
# BATTLE PICKUP_extra.accuracy               -0.0331      0.026     -1.297      0.194      -0.083       0.017
# BATTLE PICKUP_extra.hkp                     0.1095      0.059      1.861      0.063      -0.006       0.225
# BATTLE PICKUP_extra.sfpm                   -0.3224      0.085     -3.781      0.000      -0.490      -0.155
# BATTLE PICKUP_stat.hits                    -0.0014      0.002     -0.568      0.570      -0.006       0.003
# BATTLE PICKUP_stat.hs                      -0.1469      0.062     -2.368      0.018      -0.268      -0.025
# BATTLE PICKUP_stat.kills                   -0.3715      0.317     -1.173      0.241      -0.992       0.249
# BATTLE PICKUP_stat.shots                   -0.0005      0.001     -0.719      0.472      -0.002       0.001
# BATTLE PICKUP_stat.time                     0.0043      0.008      0.557      0.577      -0.011       0.020
# LMG_extra.accuracy                         -1.8184      0.154    -11.803      0.000      -2.120      -1.516
# LMG_extra.hkp                              -0.2559      0.050     -5.132      0.000      -0.354      -0.158
# LMG_extra.kpm                             -13.8376      1.732     -7.990      0.000     -17.232     -10.443
# LMG_extra.sfpm                             -0.0717      0.024     -3.009      0.003      -0.118      -0.025
# LMG_extra.spm                               0.2428      0.012     20.413      0.000       0.219       0.266
# LMG_stat.hits                              -0.0001      0.000     -0.432      0.666      -0.001       0.000
# LMG_stat.hs                                 0.0228      0.012      1.868      0.062      -0.001       0.047
# LMG_stat.kills                             -0.3794      0.317     -1.198      0.231      -1.000       0.242
# LMG_stat.score                          -5.988e-05    1.3e-05     -4.603      0.000   -8.54e-05   -3.44e-05
# LMG_stat.shots                          -2.543e-06   8.39e-06     -0.303      0.762    -1.9e-05    1.39e-05
# LMG_stat.time                               0.0042      0.008      0.543      0.587      -0.011       0.020
# GRENADE_extra.accuracy                      0.5782      0.033     17.525      0.000       0.514       0.643
# GRENADE_extra.kpm                         -13.1516      0.414    -31.797      0.000     -13.962     -12.341
# GRENADE_extra.sfpm                         -0.1313      0.039     -3.365      0.001      -0.208      -0.055
# GRENADE_extra.spm                           0.1167      0.003     37.648      0.000       0.111       0.123
# GRENADE_stat.hits                          -0.0007      0.000     -4.004      0.000      -0.001      -0.000
# GRENADE_stat.kills                         -0.3757      0.317     -1.186      0.236      -0.996       0.245
# GRENADE_stat.score                      -6.803e-05   5.19e-05     -1.312      0.190      -0.000    3.36e-05
# GRENADE_stat.shots                         -0.0014      0.001     -1.558      0.119      -0.003       0.000
# GRENADE_stat.time                           0.0062      0.008      0.791      0.429      -0.009       0.022
# SHOTGUN_stat.time                           0.0042      0.008      0.541      0.589      -0.011       0.019
# SIDEARM_extra.accuracy                     -0.0996      0.097     -1.025      0.306      -0.290       0.091
# SIDEARM_extra.hkp                          -0.0741      0.051     -1.454      0.146      -0.174       0.026
# SIDEARM_extra.kpm                         -28.0358      1.433    -19.566      0.000     -30.844     -25.227
# SIDEARM_extra.sfpm                          0.0382      0.054      0.708      0.479      -0.068       0.144
# SIDEARM_extra.spm                           0.3063      0.010     31.171      0.000       0.287       0.326
# SIDEARM_stat.hits                           0.0004      0.001      0.414      0.679      -0.001       0.002
# SIDEARM_stat.hs                            -0.0173      0.021     -0.827      0.408      -0.058       0.024
# SIDEARM_stat.kills                         -0.3709      0.317     -1.172      0.241      -0.991       0.249
# SIDEARM_stat.score                         -0.0001   2.82e-05     -3.564      0.000      -0.000   -4.53e-05
# SIDEARM_stat.shots                       -8.72e-05      0.000     -0.821      0.412      -0.000       0.000
# SIDEARM_stat.time                           0.0043      0.008      0.546      0.585      -0.011       0.020
# Infantry Fighting Vehicle_stat.destroys     0.0048      0.006      0.747      0.455      -0.008       0.017
# Infantry Fighting Vehicle_stat.kills       -0.0096      0.005     -1.891      0.059      -0.019       0.000
# Infantry Fighting Vehicle_stat.time      9.005e-05   9.89e-05      0.911      0.362      -0.000       0.000
# Anti Air_stat.destroys                      0.0133      0.007      1.923      0.055      -0.000       0.027
# Anti Air_stat.kills                        -0.0043      0.006     -0.766      0.444      -0.015       0.007
# Anti Air_stat.time                       5.332e-05      0.000      0.512      0.608      -0.000       0.000
# Transport_stat.destroys                    -0.0185      0.070     -0.263      0.793      -0.156       0.119
# Transport_stat.kills                        0.0024      0.012      0.204      0.838      -0.020       0.025
# Transport_stat.time                     -9.054e-05      0.000     -0.904      0.366      -0.000       0.000
# Air Jet Stealth_extra.spm                   0.0089      0.002      5.393      0.000       0.006       0.012
# Air Jet Stealth_stat.destroys               0.0126      0.011      1.099      0.272      -0.010       0.035
# Air Jet Stealth_stat.kills                  0.0001      0.008      0.017      0.986      -0.015       0.015
# Air Jet Stealth_stat.score                  0.0501      0.074      0.676      0.499      -0.095       0.195
# Air Jet Stealth_stat.time                7.359e-05      0.000      0.696      0.486      -0.000       0.000
# Air Helicopter Scout AH6_stat.score         0.0502      0.074      0.676      0.499      -0.095       0.195
# Air Jet Attack_extra.spm                    0.0103      0.002      5.454      0.000       0.007       0.014
# Air Jet Attack_stat.destroys                0.0069      0.007      0.971      0.332      -0.007       0.021
# Air Jet Attack_stat.kills                  -0.0026      0.006     -0.440      0.660      -0.014       0.009
# Air Jet Attack_stat.score                   0.0501      0.074      0.676      0.499      -0.095       0.195
# Air Jet Attack_stat.time                -3.825e-05      0.000     -0.374      0.709      -0.000       0.000
# Weapon Stationary _stat.destroys            0.0889      0.064      1.391      0.164      -0.036       0.214
# Weapon Stationary _stat.kills              -0.0663      0.027     -2.496      0.013      -0.118      -0.014
# Weapon Stationary _stat.time                0.0003      0.000      1.283      0.200      -0.000       0.001
# Boat_stat.destroys                         -0.2805      0.226     -1.239      0.215      -0.724       0.163
# Boat_stat.kills                            -0.0040      0.051     -0.079      0.937      -0.105       0.096
# Boat_stat.time                              0.0003      0.000      1.190      0.234      -0.000       0.001
# Air_stat.kills                              0.1053      0.046      2.312      0.021       0.016       0.195
# Air_stat.time                              -0.0005      0.001     -0.583      0.560      -0.002       0.001
# Main Battle Tanks_extra.spm                 0.0622      0.002     35.850      0.000       0.059       0.066
# Main Battle Tanks_stat.destroys             0.0050      0.004      1.224      0.221      -0.003       0.013
# Main Battle Tanks_stat.kills               -0.0071      0.005     -1.463      0.143      -0.017       0.002
# Main Battle Tanks_stat.score                0.0502      0.074      0.676      0.499      -0.095       0.195
# Main Battle Tanks_stat.time              1.838e-05   9.97e-05      0.184      0.854      -0.000       0.000
# Air Helicopter Scout_stat.destroys          0.0071      0.006      1.256      0.209      -0.004       0.018
# Air Helicopter Scout_stat.kills            -0.0072      0.005     -1.468      0.142      -0.017       0.002
# Air Helicopter Scout_stat.time           3.494e-05   9.86e-05      0.354      0.723      -0.000       0.000
# Air Helicopter Attack_extra.spm             0.0158      0.001     12.865      0.000       0.013       0.018
# Air Helicopter Attack_stat.destroys         0.0116      0.003      3.466      0.001       0.005       0.018
# Air Helicopter Attack_stat.kills           -0.0072      0.005     -1.493      0.136      -0.017       0.002
# Air Helicopter Attack_stat.score            0.0502      0.074      0.676      0.499      -0.095       0.195
# Air Helicopter Attack_stat.time          8.695e-06   9.76e-05      0.089      0.929      -0.000       0.000
# Mobile Artillery_stat.destroys              0.1143      0.124      0.919      0.358      -0.130       0.358
# Mobile Artillery_stat.kills                -0.0414      0.049     -0.845      0.398      -0.137       0.055
# Mobile Artillery_stat.time               6.936e-05      0.000      0.197      0.844      -0.001       0.001
# Transport UH-1Y Venom_stat.time            -0.0012      0.001     -0.960      0.337      -0.004       0.001
# Soldier Equiment_stat.destroys             -0.0194      0.008     -2.504      0.012      -0.035      -0.004
# Soldier Equiment_stat.kills                -0.0010      0.006     -0.167      0.867      -0.012       0.010
# Fast Attack Craft_extra.spm                 0.0007      0.000      7.167      0.000       0.001       0.001
# Fast Attack Craft_stat.destroys            -0.0515      0.035     -1.468      0.142      -0.120       0.017
# Fast Attack Craft_stat.kills                0.0074      0.006      1.176      0.240      -0.005       0.020
# Fast Attack Craft_stat.score                0.0502      0.074      0.676      0.499      -0.095       0.195
# Fast Attack Craft_stat.time                -0.0001      0.000     -0.613      0.540      -0.001       0.000
# IFV BTR 90_stat.score                       0.0502      0.074      0.676      0.499      -0.095       0.195
# AA LAV-AD_stat.score                        0.0501      0.074      0.676      0.499      -0.095       0.195
# minutes                                     0.0015      0.001      2.132      0.033       0.000       0.003
# kpm                                        -9.3656      0.455    -20.582      0.000     -10.258      -8.474
# ==============================================================================
# Omnibus:                    13308.198   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3212623.454
# Skew:                          -0.493   Prob(JB):                         0.00
# Kurtosis:                      48.589   Cond. No.                     1.27e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.23e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Using the OLS model, we can extract variables that are significant to predicting spm
df2 = pd.DataFrame(model.pvalues[model.pvalues < 0.01])
sig_var = list(df2.index)
len(sig_var)
# Out:
# 91

# %%
print(list(sig_var))
# Out:
# ['avengerKills', 'deaths', 'extra.accuracy', 'extra.hkp', 'extra.kdr', 'extra.khp', 'extra.sfpm', 'extra.vehKillsP', 'extra.vehTimeP', 'extra.weaKillsP', 'extra.weaKpm', 'extra.weaTimeP', 'extra.wlr', 'flagDefend', 'heals', 'killAssists', 'killStreakBonus', 'kits.assault.spm', 'kits.assault.stars', 'kits.assault.time', 'kits.commander.spm', 'kits.engineer.spm', 'kits.engineer.stars', 'kits.engineer.time', 'kits.recon.spm', 'kits.recon.stars', 'kits.recon.time', 'kits.support.spm', 'kits.support.stars', 'kits.support.time', 'longestHeadshot', 'numLosses', 'numRounds', 'numWins', 'resupplies', 'scores.award', 'scores.general', 'scores.score', 'scores.totalScore', 'Domination_score', 'GADGET_extra.accuracy', 'GADGET_extra.sfpm', 'SNIPER RIFLE_extra.accuracy', 'SNIPER RIFLE_extra.hkp', 'SNIPER RIFLE_stat.score', 'PDW_extra.accuracy', 'PDW_extra.hkp', 'PDW_extra.kpm', 'PDW_extra.sfpm', 'PDW_extra.spm', 'PDW_stat.score', 'CARBINE_extra.hkp', 'CARBINE_extra.kpm', 'CARBINE_extra.sfpm', 'CARBINE_extra.spm', 'CARBINE_stat.score', 'BATTLE PICKUP_extra.sfpm', 'LMG_extra.accuracy', 'LMG_extra.hkp', 'LMG_extra.kpm', 'LMG_extra.sfpm', 'LMG_extra.spm', 'LMG_stat.score', 'GRENADE_extra.accuracy', 'GRENADE_extra.kpm', 'GRENADE_extra.sfpm', 'GRENADE_extra.spm', 'GRENADE_stat.hits', 'DMR_extra.accuracy', 'DMR_extra.hkp', 'DMR_extra.kpm', 'DMR_extra.spm', 'ASSAULT RIFLE_extra.accuracy', 'ASSAULT RIFLE_extra.hkp', 'ASSAULT RIFLE_extra.kpm', 'ASSAULT RIFLE_extra.sfpm', 'ASSAULT RIFLE_extra.spm', 'ASSAULT RIFLE_stat.hits', 'ASSAULT RIFLE_stat.score', 'SHOTGUN_extra.accuracy', 'SHOTGUN_stat.score', 'SIDEARM_extra.kpm', 'SIDEARM_extra.spm', 'SIDEARM_stat.score', 'Air Jet Stealth_extra.spm', 'Air Jet Attack_extra.spm', 'Main Battle Tanks_extra.spm', 'Air Helicopter Attack_extra.spm', 'Air Helicopter Attack_stat.destroys', 'Fast Attack Craft_extra.spm', 'kpm']

# %%
sig_var.append('spm')

# %%
x_new = x_cols[sig_var]
x_new = x_new.reset_index(drop=True)

# %%
x_new.shape
# Out:
# (37081, 92)

# %%
X = x_new.drop(['spm'],axis = 1)
y = x_new.spm

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    spm   R-squared (uncentered):                   0.940
# Model:                            OLS   Adj. R-squared (uncentered):              0.939
# Method:                 Least Squares   F-statistic:                              6384.
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):                        0.00
# Time:                        16:30:43   Log-Likelihood:                     -2.2925e+05
# No. Observations:               37081   AIC:                                  4.587e+05
# Df Residuals:                   36991   BIC:                                  4.594e+05
# Df Model:                          90
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# avengerKills                            0.0155      0.002      8.674      0.000       0.012       0.019
# deaths                                  0.0005      0.000      2.886      0.004       0.000       0.001
# extra.accuracy                          2.4835      0.245     10.137      0.000       2.003       2.964
# extra.hkp                              -1.0694      0.143     -7.460      0.000      -1.350      -0.788
# extra.kdr                              24.4575      1.243     19.672      0.000      22.021      26.894
# extra.khp                              -0.4290      0.154     -2.787      0.005      -0.731      -0.127
# extra.sfpm                              0.9864      0.068     14.539      0.000       0.853       1.119
# extra.vehKillsP                        -1.6131      0.145    -11.149      0.000      -1.897      -1.330
# extra.vehTimeP                          3.7553      0.179     20.962      0.000       3.404       4.106
# extra.weaKillsP                        -2.1546      0.101    -21.269      0.000      -2.353      -1.956
# extra.weaKpm                           34.1077      2.124     16.056      0.000      29.944      38.271
# extra.weaTimeP                          5.5569      0.131     42.494      0.000       5.301       5.813
# extra.wlr                              13.3244      0.732     18.191      0.000      11.889      14.760
# flagDefend                           7.041e-05      0.000      0.159      0.874      -0.001       0.001
# heals                                  -0.0005      0.000     -4.873      0.000      -0.001      -0.000
# killAssists                            -0.0108      0.001     -7.578      0.000      -0.014      -0.008
# killStreakBonus                         0.0477      0.074      0.646      0.519      -0.097       0.192
# kits.assault.spm                        0.0860      0.002     45.810      0.000       0.082       0.090
# kits.assault.stars                      0.5605      0.118      4.749      0.000       0.329       0.792
# kits.assault.time                   -2.999e-05   7.08e-06     -4.236      0.000   -4.39e-05   -1.61e-05
# kits.commander.spm                      0.0035      0.001      3.321      0.001       0.001       0.006
# kits.engineer.spm                       0.0589      0.002     36.274      0.000       0.056       0.062
# kits.engineer.stars                     0.4245      0.104      4.078      0.000       0.221       0.629
# kits.engineer.time                  -2.149e-05   6.89e-06     -3.121      0.002    -3.5e-05   -7.99e-06
# kits.recon.spm                          0.0274      0.001     19.915      0.000       0.025       0.030
# kits.recon.stars                        0.3697      0.074      4.984      0.000       0.224       0.515
# kits.recon.time                     -2.595e-05   5.37e-06     -4.833      0.000   -3.65e-05   -1.54e-05
# kits.support.spm                        0.0316      0.001     24.614      0.000       0.029       0.034
# kits.support.stars                      0.3114      0.111      2.815      0.005       0.095       0.528
# kits.support.time                    -1.19e-05   5.32e-06     -2.238      0.025   -2.23e-05   -1.48e-06
# longestHeadshot                        -0.0241      0.003     -9.157      0.000      -0.029      -0.019
# numLosses                               0.0104      0.004      2.383      0.017       0.002       0.019
# numRounds                              -0.0178      0.002     -7.125      0.000      -0.023      -0.013
# numWins                                 0.0151      0.004      4.016      0.000       0.008       0.022
# resupplies                             -0.0005      0.000     -3.742      0.000      -0.001      -0.000
# scores.award                         1.988e-05   9.64e-07     20.614      0.000     1.8e-05    2.18e-05
# scores.general                      -1.568e-05   9.52e-07    -16.466      0.000   -1.75e-05   -1.38e-05
# scores.score                          2.71e-07   2.31e-07      1.173      0.241   -1.82e-07    7.24e-07
# scores.totalScore                    3.479e-07   2.31e-07      1.506      0.132   -1.05e-07    8.01e-07
# Domination_score                    -1.209e-05   8.46e-06     -1.428      0.153   -2.87e-05     4.5e-06
# GADGET_extra.accuracy                  -0.0569      0.044     -1.296      0.195      -0.143       0.029
# GADGET_extra.sfpm                       0.0775      0.023      3.365      0.001       0.032       0.123
# SNIPER RIFLE_extra.accuracy            -0.4748      0.062     -7.717      0.000      -0.595      -0.354
# SNIPER RIFLE_extra.hkp                  0.1948      0.032      6.120      0.000       0.132       0.257
# SNIPER RIFLE_stat.score             -2.189e-05   2.71e-06     -8.072      0.000   -2.72e-05   -1.66e-05
# PDW_extra.accuracy                     -0.5682      0.155     -3.672      0.000      -0.871      -0.265
# PDW_extra.hkp                          -0.0658      0.045     -1.468      0.142      -0.154       0.022
# PDW_extra.kpm                         -18.8724      1.726    -10.933      0.000     -22.256     -15.489
# PDW_extra.sfpm                         -0.2743      0.031     -8.763      0.000      -0.336      -0.213
# PDW_extra.spm                           0.2174      0.013     17.036      0.000       0.192       0.242
# PDW_stat.score                      -1.668e-05   2.37e-06     -7.050      0.000   -2.13e-05    -1.2e-05
# CARBINE_extra.hkp                       0.0025      0.050      0.050      0.960      -0.096       0.101
# CARBINE_extra.kpm                     -29.4096      1.758    -16.731      0.000     -32.855     -25.964
# CARBINE_extra.sfpm                     -0.1201      0.029     -4.160      0.000      -0.177      -0.064
# CARBINE_extra.spm                       0.3061      0.012     24.846      0.000       0.282       0.330
# CARBINE_stat.score                  -1.723e-05   1.87e-06     -9.220      0.000   -2.09e-05   -1.36e-05
# BATTLE PICKUP_extra.sfpm               -0.2597      0.086     -3.034      0.002      -0.427      -0.092
# LMG_extra.accuracy                     -1.8675      0.156    -11.968      0.000      -2.173      -1.562
# LMG_extra.hkp                          -0.1605      0.051     -3.158      0.002      -0.260      -0.061
# LMG_extra.kpm                         -17.3479      1.760     -9.860      0.000     -20.797     -13.899
# LMG_extra.sfpm                         -0.0234      0.024     -0.983      0.326      -0.070       0.023
# LMG_extra.spm                           0.2476      0.012     20.543      0.000       0.224       0.271
# LMG_stat.score                      -1.783e-05   2.33e-06     -7.654      0.000   -2.24e-05   -1.33e-05
# GRENADE_extra.accuracy                  0.6008      0.033     18.442      0.000       0.537       0.665
# GRENADE_extra.kpm                     -13.7699      0.420    -32.804      0.000     -14.593     -12.947
# GRENADE_extra.sfpm                     -0.2506      0.039     -6.375      0.000      -0.328      -0.174
# GRENADE_extra.spm                       0.1204      0.003     38.424      0.000       0.114       0.127
# GRENADE_stat.hits                      -0.0002      0.000     -1.843      0.065      -0.000    1.51e-05
# DMR_extra.accuracy                     -0.4867      0.091     -5.347      0.000      -0.665      -0.308
# DMR_extra.hkp                          -0.0297      0.057     -0.524      0.601      -0.141       0.082
# DMR_extra.kpm                         -24.6587      1.595    -15.460      0.000     -27.785     -21.533
# DMR_extra.spm                           0.1895      0.012     15.913      0.000       0.166       0.213
# ASSAULT RIFLE_extra.accuracy           -0.8182      0.081    -10.104      0.000      -0.977      -0.659
# ASSAULT RIFLE_extra.hkp                -0.1196      0.068     -1.765      0.078      -0.252       0.013
# ASSAULT RIFLE_extra.kpm               -34.2148      1.993    -17.164      0.000     -38.122     -30.308
# ASSAULT RIFLE_extra.sfpm               -0.5743      0.055    -10.410      0.000      -0.682      -0.466
# ASSAULT RIFLE_extra.spm                 0.6658      0.015     42.985      0.000       0.635       0.696
# ASSAULT RIFLE_stat.hits                 0.0009   8.89e-05     10.121      0.000       0.001       0.001
# ASSAULT RIFLE_stat.score            -5.095e-05   3.99e-06    -12.760      0.000   -5.88e-05   -4.31e-05
# SHOTGUN_extra.accuracy                  0.0522      0.022      2.325      0.020       0.008       0.096
# SHOTGUN_stat.score                  -1.753e-05    2.5e-06     -7.012      0.000   -2.24e-05   -1.26e-05
# SIDEARM_extra.kpm                     -27.4108      1.388    -19.754      0.000     -30.131     -24.691
# SIDEARM_extra.spm                       0.3068      0.010     31.487      0.000       0.288       0.326
# SIDEARM_stat.score                  -4.322e-05   6.43e-06     -6.723      0.000   -5.58e-05   -3.06e-05
# Air Jet Stealth_extra.spm               0.0100      0.002      5.930      0.000       0.007       0.013
# Air Jet Attack_extra.spm                0.0113      0.002      5.884      0.000       0.008       0.015
# Main Battle Tanks_extra.spm             0.0679      0.002     38.397      0.000       0.064       0.071
# Air Helicopter Attack_extra.spm         0.0180      0.001     14.279      0.000       0.016       0.020
# Air Helicopter Attack_stat.destroys     0.0038      0.001      6.243      0.000       0.003       0.005
# Fast Attack Craft_extra.spm             0.0008      0.000      7.720      0.000       0.001       0.001
# kpm                                    -9.0429      0.454    -19.920      0.000      -9.933      -8.153
# ==============================================================================
# Omnibus:                    15196.397   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          4068516.024
# Skew:                          -0.758   Prob(JB):                         0.00
# Kurtosis:                      54.293   Cond. No.                     1.12e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.1e-13. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# **Conclusion**: Based on the OLS, model, we can conclude that there are a significant amount of variables that contribute to a player's high spm score, these include nearly all weapons and kit uses, along with Air Jet, Tank and Helicopter usage. However, 91 features are still too complicated to explain this model, in the code, below, we use PCA to reduce our dimensions.

# %% [markdown]
# <hr>

# %%
# since we have 92 columns/dimensions, we should consider using PCA to reduce dimensions
from sklearn.decomposition import PCA

# %%
# scale the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(x_new)

# %%
import sklearn.decomposition
pca = sklearn.decomposition.PCA()
pca.fit(scaled_data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
# Plot the explained variance by each component
_ = plt.figure(figsize=(15,8))
_ = plt.title('PCA Components vs Explained Variance')
_ = plt.plot(pca.explained_variance_[:10])
_ = plt.xlabel('The Kth Number of Component')
_ = plt.ylabel('Explained Varianced')
_ = plt.show()

# %%
# create model and set components to 3, then fit model
pca = sklearn.decomposition.PCA(n_components=8, random_state=0)
x_new['pc1'] = pca.fit_transform(x_new)[:,0]
x_new['pc2'] = pca.fit_transform(x_new)[:,1]
x_new['pc3'] = pca.fit_transform(x_new)[:,2]
x_new['pc4'] = pca.fit_transform(x_new)[:,3]
x_new['pc5'] = pca.fit_transform(x_new)[:,4]
x_new['pc6'] = pca.fit_transform(x_new)[:,5]
x_new['pc7'] = pca.fit_transform(x_new)[:,6]
x_new['pc8'] = pca.fit_transform(x_new)[:,7]

# %%
# move x,y,z to the front
#x_new = x_new[ ['z'] + [ col for col in x_new.columns if col != 'z' ] ]
#x_new = x_new[ ['y'] + [ col for col in x_new.columns if col != 'y' ] ]
#x_new = x_new[ ['x'] + [ col for col in x_new.columns if col != 'x' ] ]

# %%
x_new.head()
# Out:
#    avengerKills  deaths  extra.accuracy  extra.hkp  extra.kdr  extra.khp  \
# 0         62235  286403              11         15          2         27
# 1         51888  131168              11         14          3         16
# 2         51266  166087              17         21          3         18
# 3         51743  312395              14         11          1         19
# 4         30049  132163              11          9          3         12
#
#    extra.sfpm  extra.vehKillsP  extra.vehTimeP  extra.weaKillsP  ...  \
# 0          42                6               7               92  ...
# 1          72               20              21               79  ...
# 2          53               23              20               76  ...
# 3          56               22              24               77  ...
# 4          64               58              38               41  ...
#
#         kpm     spm           pc1           pc2           pc3           pc4  \
# 0  1.368540  941.95  5.969639e+08 -8.439843e+05  2.727433e+07  2.646258e+06
# 1  1.384666  939.07  4.957584e+08  1.048668e+06 -2.328475e+07 -6.966198e+06
# 2  1.737936  971.45  4.982960e+08  5.181235e+05 -1.693180e+07  5.683155e+06
# 3  1.647379  976.21  4.539191e+08 -2.743871e+05  1.161428e+07  6.234583e+06
# 4  0.958514  660.64  4.535830e+08 -2.033513e+05  1.030291e+06  1.114160e+07
#
#             pc5           pc6           pc7           pc8
# 0 -1.465301e+07  3.498052e+07  5.246323e+07  1.406991e+06
# 1  1.285365e+07 -4.436946e+06  3.303555e+06  1.517513e+06
# 2  2.094715e+05  7.360406e+06 -9.630978e+06 -1.892635e+07
# 3  2.058098e+06 -8.436610e+06  1.005854e+06  2.610134e+05
# 4 -8.221573e+05  3.997949e+06 -1.928748e+06  1.208913e+06
#
# [5 rows x 100 columns]

# %%
x_tmp = x_new[['pc1','pc2','pc3','pc4','pc5','pc6','pc7','pc8','spm']]

# %%
x_tmp
# Out:
#                 pc1           pc2           pc3           pc4           pc5  \
# 0      5.969639e+08 -8.439843e+05  2.727433e+07  2.646258e+06 -1.465301e+07
# 1      4.957584e+08  1.048668e+06 -2.328475e+07 -6.966198e+06  1.285365e+07
# 2      4.982960e+08  5.181235e+05 -1.693180e+07  5.683155e+06  2.094715e+05
# 3      4.539191e+08 -2.743871e+05  1.161428e+07  6.234583e+06  2.058098e+06
# 4      4.535830e+08 -2.033513e+05  1.030291e+06  1.114160e+07 -8.221573e+05
# ...             ...           ...           ...           ...           ...
# 37076 -1.151925e+07 -1.442159e+04  1.431440e+05  2.943601e+05  1.168217e+05
# 37077 -1.105941e+07 -1.452726e+04  1.151347e+05  2.231818e+05  8.126040e+04
# 37078 -1.089903e+07 -1.430093e+04  1.487103e+05  1.859023e+05  1.136104e+05
# 37079 -1.151665e+07 -1.436277e+04  1.413763e+05  2.955132e+05  1.166043e+05
# 37080 -1.151887e+07 -1.441238e+04  1.417369e+05  2.941245e+05  1.158238e+05
#
#                 pc6           pc7           pc8     spm
# 0      3.498052e+07  5.246323e+07  1.406991e+06  941.95
# 1     -4.436946e+06  3.303555e+06  1.517513e+06  939.07
# 2      7.360406e+06 -9.630978e+06 -1.892635e+07  971.45
# 3     -8.436610e+06  1.005854e+06  2.610134e+05  976.21
# 4      3.997949e+06 -1.928748e+06  1.208913e+06  660.64
# ...             ...           ...           ...     ...
# 37076 -3.911165e+04  5.638476e+04 -9.076511e+03  190.96
# 37077 -2.427735e+04  3.088353e+04 -2.340111e+04  113.90
# 37078 -2.613755e+04  3.680997e+04 -2.978456e+03  149.38
# 37079 -3.953807e+04  5.661919e+04 -9.763417e+03  372.53
# 37080 -3.896830e+04  5.603314e+04 -9.445094e+03  214.70
#
# [37081 rows x 9 columns]

# %%
X = x_tmp.drop(['spm'],axis = 1)
y = x_tmp.spm

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
print(model.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    spm   R-squared (uncentered):                   0.070
# Model:                            OLS   Adj. R-squared (uncentered):              0.069
# Method:                 Least Squares   F-statistic:                              346.6
# Date:                Sun, 03 Nov 2019   Prob (F-statistic):                        0.00
# Time:                        16:31:21   Log-Likelihood:                     -2.7992e+05
# No. Observations:               37081   AIC:                                  5.599e+05
# Df Residuals:                   37073   BIC:                                  5.599e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# pc1         2.715e-06   7.87e-08     34.493      0.000    2.56e-06    2.87e-06
# pc2         1.478e-06      9e-07      1.643      0.100   -2.86e-07    3.24e-06
# pc3        -2.667e-05   1.52e-06    -17.576      0.000   -2.96e-05   -2.37e-05
# pc4        -5.998e-05   2.06e-06    -29.180      0.000    -6.4e-05   -5.59e-05
# pc5        -3.351e-05   3.04e-06    -11.025      0.000   -3.95e-05   -2.76e-05
# pc6         2.214e-05   3.65e-06      6.068      0.000     1.5e-05    2.93e-05
# pc7        -5.536e-05   4.42e-06    -12.526      0.000    -6.4e-05   -4.67e-05
# pc8         5.605e-05   5.47e-06     10.245      0.000    4.53e-05    6.68e-05
# ==============================================================================
# Omnibus:                    11059.531   Durbin-Watson:                   0.317
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            39800.948
# Skew:                           1.479   Prob(JB):                         0.00
# Kurtosis:                       7.125   Cond. No.                         69.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
